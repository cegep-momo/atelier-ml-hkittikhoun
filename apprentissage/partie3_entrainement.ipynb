# %% [markdown]
# Partie 3

# %% [markdown]
# Implémentation d'une entraînement de modèles de régréssion.

# %%
import pandas as pd

pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('future.no_silent_downcasting', True)

# %%
#Chargement du dataset avec pour séparateur des tabulations
dataset = pd.read_csv("datas/dataset.csv",delimiter='\t')

#Suppression des lignes ayant des valeurs manquantes
dataset = dataset.dropna(axis=0, how='any')

# %%
#X = on prend toutes les données, mais uniquement les features 4 à 11
# POINTS_ATTAQUE;POINTS_DEFFENCE;POINTS_ATTAQUE_SPECIALE;POINT_DEFENSE_SPECIALE;POINTS_VITESSE;NOMBRE_GENERATIONS
X = dataset.iloc[:, 5:12].values

#y = on prend uniquement la feature POURCENTAGE_DE_VICTOIRE (17ème feature)
y = dataset.iloc[:, 17].values

#Construction du jeu d'entrainement et du jeu de tests
from sklearn.model_selection import train_test_split
X_APPRENTISSAGE, X_VALIDATION, Y_APPRENTISSAGE, Y_VALIDATION = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
#---- ALGORITHME 1: REGRESSION LINEAIRE -----
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

#Choix de l'algorithme
algorithme = LinearRegression()

#Apprentissage à l'aide de la fonction fit
#Apprentisage effectué sur le jeu de données d'apprentissage
algorithme.fit(X_APPRENTISSAGE, Y_APPRENTISSAGE)

#Realisation de prédictions sur le jeu de tests (validation)
predictions = algorithme.predict(X_VALIDATION)

#Calcul de la précision de l'apprentissage à l'aide de la
#fonction r2_score en comparant les valeurs prédites
#(predictions) et les valeurs attendues (Y_VALIDATION)
precision = r2_score(Y_VALIDATION, predictions)

print(">> ----------- REGRESSION LINEAIRE -----------")
print(">> Precision = "+str(precision))
print("------------------------------------------")
# Out:
# >> ----------- REGRESSION LINEAIRE -----------
# >> Precision = 0.9043488485570964
# ------------------------------------------

# %% [markdown]
# L'algorithme de régression linéaire nous donne une précsion de 90,43%. Ce qui signifie que le modèle explique environ 90% de la variance dans les résultats de combat.

# %%
#Choix de l'algorithme
from sklearn.tree import DecisionTreeRegressor
algorithme = DecisionTreeRegressor()
algorithme.fit(X_APPRENTISSAGE, Y_APPRENTISSAGE)
predictions = algorithme.predict(X_VALIDATION)
precision = r2_score(Y_VALIDATION, predictions)

print(">> ----------- ARBRES DE DECISIONS -----------")
print(">> Precision = "+str(precision))
print("------------------------------------------")
# Out:
# >> ----------- ARBRES DE DECISIONS -----------
# >> Precision = 0.8374477926671655
# ------------------------------------------

# %% [markdown]
# L'algorithme d'arbre de décision nous donne une précsion de 83,74%. Ce qui signifie que le modèle est moins bon que la regréssion linéaire.

# %%
#Choix de l'algorithme
from sklearn.ensemble import RandomForestRegressor
algorithme = RandomForestRegressor()
algorithme.fit(X_APPRENTISSAGE, Y_APPRENTISSAGE)
predictions = algorithme.predict(X_VALIDATION)
precision = r2_score(Y_VALIDATION, predictions)

print(">> ----------- FORETS ALEATOIRES -----------")
print(">> Precision = "+str(precision))
print("------------------------------------------")
# Out:
# >> ----------- FORETS ALEATOIRES -----------
# >> Precision = 0.9392810311901575
# ------------------------------------------

# %% [markdown]
# L'algorithme de fôret aléatoire nous donne une précsion de 93,93%. Ce qui est le meilleur résultats des trois algorithmes testés.

# %%
# Sauvegarde du modèle d'apprentissage
import joblib
fichier = 'modele/modele_pokemon.mod'
joblib.dump(algorithme, fichier)
# Out:
# ['modele/modele_pokemon.mod']

# %%
# Mesure de la précision sur les données d'apprentissage
predictions = algorithme.predict(X_VALIDATION)
precision_apprentissage = algorithme.score(X_APPRENTISSAGE,Y_APPRENTISSAGE)
precision = r2_score(Y_VALIDATION, predictions)

# %%
# Affichage des résultats de précision
print("=== SURAPPRENTISSAGE OU SOUS-APPRENTISSAGE ===")
print(f"Précision sur données de validation: {precision}")
print(f"Précision sur données d'entraînement: {precision_apprentissage}")

# Calcul et affichage de la différence pour détecter le surapprentissage
difference = abs(precision_apprentissage - precision)
print(f"Différence (détection surapprentissage): {difference}")

# Interprétation simple
if difference < 0.05:
    print("Pas de surapprentissage détecté")
elif difference < 0.1:
    print("Léger surapprentissage")
else:
    print("Surapprentissage important!")
# Out:
# === SURAPPRENTISSAGE OU SOUS-APPRENTISSAGE ===
# Précision sur données de validation: 0.9392810311901575
# Précision sur données d'entraînement: 0.9915859768343023
# Différence (détection surapprentissage): 0.052304945644144785
# Léger surapprentissage

# %% [markdown]
# Le modèle Random Forest est performant avec 93,93% de précision et présente un léger surapprentissage.
